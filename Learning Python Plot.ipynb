# %% [markdown]
# # Test code for learning Python plot

# %%
print('hello,world!')
# Out:
# hello,world!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('some number')
# Out:
# Text(0,0.5,'some number')

# %%
plt.plot([1,2,3,4],[1,4,9,16])
